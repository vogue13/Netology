# %% [markdown]
# # Дипломная работа по курсу "Аналитик Данных"
#
# # Тема " Анализ факторов, влияющих на отток пользователей кредитных карт банка, и построение модели, предсказывающей отток пользователей"
#
#
# # Источник данных:  https://www.kaggle.com/sakshigoyal7/credit-card-customers

# %% [markdown]
# ## 1. Предобработка данных

# %%
#ИМПОРТ ПАКЕТОВ ПРИЛОЖЕНИЙ

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#ИМПОРТ ДАННЫХ
df = pd.read_csv('BankChurners.csv')
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %%
#ОЧИСТКА НЕРЕЛЕВАНТНЫХ ДАННЫХ
df.drop(df.columns[[-1, -2]], axis=1, inplace=True) #убираю последние две колонки, в описании было рекомендовано так сделать
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                  39  ...                       1                      3
# 1                  44  ...                       1                      2
# 2                  36  ...                       1                      0
# 3                  34  ...                       4                      1
# 4                  21  ...                       1                      0
# ...               ...  ...                     ...                    ...
# 10122              40  ...                       2                      3
# 10123              25  ...                       2                      3
# 10124              36  ...                       3                      4
# 10125              36  ...                       3                      3
# 10126              25  ...                       2                      4
#
#        Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0           12691.0                  777          11914.0
# 1            8256.0                  864           7392.0
# 2            3418.0                    0           3418.0
# 3            3313.0                 2517            796.0
# 4            4716.0                    0           4716.0
# ...             ...                  ...              ...
# 10122        4003.0                 1851           2152.0
# 10123        4277.0                 2186           2091.0
# 10124        5409.0                    0           5409.0
# 10125        5281.0                    0           5281.0
# 10126       10388.0                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [10127 rows x 21 columns]

# %%
#ПРОВЕРКА ПРОПУСКОВ ДАННЫХ 
df.isna().sum().reset_index()
# Out:
#                        index  0
# 0                  CLIENTNUM  0
# 1             Attrition_Flag  0
# 2               Customer_Age  0
# 3                     Gender  0
# 4            Dependent_count  0
# 5            Education_Level  0
# 6             Marital_Status  0
# 7            Income_Category  0
# 8              Card_Category  0
# 9             Months_on_book  0
# 10  Total_Relationship_Count  0
# 11    Months_Inactive_12_mon  0
# 12     Contacts_Count_12_mon  0
# 13              Credit_Limit  0
# 14       Total_Revolving_Bal  0
# 15           Avg_Open_To_Buy  0
# 16      Total_Amt_Chng_Q4_Q1  0
# 17           Total_Trans_Amt  0
# 18            Total_Trans_Ct  0
# 19       Total_Ct_Chng_Q4_Q1  0
# 20     Avg_Utilization_Ratio  0

# %% [markdown]
# Проверка показала, что отсутствующих данных не наблюдается.

# %%
# ИЗМЕНЕНИЕ НОМЕРА КЛИЕНТА НА ИНДЕКС
df = df.set_index("CLIENTNUM")

# %%
#ПРОВЕРКА КОРРЕКТНОСТИ ДАННЫХ
df.describe()
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %% [markdown]
# Максимальные и минимальные значения находятся в рамках потенциально возможных значений, аномалии в данных не наблюдаются.

# %%
#ПЕРЕВОД КАТЕГОРИАЛЬНЫХ ЗНАЧЕНИЙ В ЧИСЛОВЫЕ
df['Attrition_Flag_Num'] = df['Attrition_Flag'].map({'Existing Customer':1, 'Attrited Customer':0})
df['Gender_Num'] = df['Gender'].map({'M':0, 'F':1})
df['Income_Category_Num'] = df['Income_Category'].map({'Unknown':1, 'Less than $40K':2, '$40K - $60K':3, '$60K - $80K':4, '$80K - $120K':5, '$120K +':6})
df['Marital_Status_Num'] = df['Marital_Status'].map({'Unknown':1, 'Divorced':2, 'Single':3, 'Married':4})
df['Education_Level_Num'] = df['Education_Level'].map({'Unknown':1, 'Uneducated':1, 'High School':2, 'College':3,'Graduate':4,'Post-Graduate':5,'Doctorate':6})
df['Card_Category_Num'] = df['Card_Category'].map({'Blue':1, 'Silver':2, 'Gold':3, 'Platinum':4})
df.drop(columns=['Attrition_Flag', 'Gender', 'Income_Category', 'Marital_Status', 'Education_Level', 'Card_Category'], inplace=True)
df
# Out:
#            Customer_Age  Dependent_count  Months_on_book  \
# CLIENTNUM
# 768805383            45                3              39
# 818770008            49                5              44
# 713982108            51                3              36
# 769911858            40                4              34
# 709106358            40                3              21
# ...                 ...              ...             ...
# 772366833            50                2              40
# 710638233            41                2              25
# 716506083            44                1              36
# 717406983            30                2              36
# 714337233            43                2              25
#
#            Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 768805383                         5                       1
# 818770008                         6                       1
# 713982108                         4                       1
# 769911858                         3                       4
# 709106358                         5                       1
# ...                             ...                     ...
# 772366833                         3                       2
# 710638233                         4                       2
# 716506083                         5                       3
# 717406983                         4                       3
# 714337233                         6                       2
#
#            Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# CLIENTNUM
# 768805383                      3       12691.0                  777
# 818770008                      2        8256.0                  864
# 713982108                      0        3418.0                    0
# 769911858                      1        3313.0                 2517
# 709106358                      0        4716.0                    0
# ...                          ...           ...                  ...
# 772366833                      3        4003.0                 1851
# 710638233                      3        4277.0                 2186
# 716506083                      4        5409.0                    0
# 717406983                      3        5281.0                    0
# 714337233                      4       10388.0                 1961
#
#            Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM
# 768805383          11914.0                 1.335             1144
# 818770008           7392.0                 1.541             1291
# 713982108           3418.0                 2.594             1887
# 769911858            796.0                 1.405             1171
# 709106358           4716.0                 2.175              816
# ...                    ...                   ...              ...
# 772366833           2152.0                 0.703            15476
# 710638233           2091.0                 0.804             8764
# 716506083           5409.0                 0.819            10291
# 717406983           5281.0                 0.535             8395
# 714337233           8427.0                 0.703            10294
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# CLIENTNUM
# 768805383              42                1.625                  0.061
# 818770008              33                3.714                  0.105
# 713982108              20                2.333                  0.000
# 769911858              20                2.333                  0.760
# 709106358              28                2.500                  0.000
# ...                   ...                  ...                    ...
# 772366833             117                0.857                  0.462
# 710638233              69                0.683                  0.511
# 716506083              60                0.818                  0.000
# 717406983              62                0.722                  0.000
# 714337233              61                0.649                  0.189
#
#            Attrition_Flag_Num  Gender_Num  Income_Category_Num  \
# CLIENTNUM
# 768805383                   1           0                    4
# 818770008                   1           1                    2
# 713982108                   1           0                    5
# 769911858                   1           1                    2
# 709106358                   1           0                    4
# ...                       ...         ...                  ...
# 772366833                   1           0                    3
# 710638233                   0           0                    3
# 716506083                   0           1                    2
# 717406983                   0           0                    3
# 714337233                   0           1                    2
#
#            Marital_Status_Num  Education_Level_Num  Card_Category_Num
# CLIENTNUM
# 768805383                   4                    2                  1
# 818770008                   3                    4                  1
# 713982108                   4                    4                  1
# 769911858                   1                    2                  1
# 709106358                   4                    1                  1
# ...                       ...                  ...                ...
# 772366833                   3                    4                  1
# 710638233                   2                    1                  1
# 716506083                   4                    2                  1
# 717406983                   1                    4                  1
# 714337233                   4                    4                  2
#
# [10127 rows x 20 columns]

# %% [markdown]
# Для дальнейшего анализа категориальные значения были переведены в чиcловые. Категориальные данные, которые являются порядковыми (например, 'Income_Category_Num', 'Education_Level_Num'), были переведены в числа соотвественно их рангу.

# %% [markdown]
# ## 2. Анализ и визуализация данных

# %% [markdown]
# Параметры модели:
#
# Демографические показатели:
#
# * Customer_Age Возраст клиента
# * Dependent_count Количество иждивенцев
# * Gender_Num Пол клиента
# * Income_Category_Num Средний доход клиента
# * Education_Level_Num Уровень образования клиента
#
# Банковские показатели:
# * Months_on_book Длительность обслуживания в банке, месяцы
# * Total_Relationship_Count Общее количество продуктов банка, используемых клиентом
# * Months_Inactive_12_mon Количество месяцев неактивности клиента за последние 12 месяцев
# * Contacts_Count_12_mon Количество контрактов за последние 12 месяцев
# * Credit_Limit Кредитный лимит по кредитной карте
# * Total_Revolving_Bal Общий оборот по кредитной карте
# * Avg_Open_To_Buy Доступный остаток кредитной карты (среднее за 12 месяцев)
# * Total_Amt_Chng_Q4_Q1 Изменение в объеме трансакциий (4 квартала по сравнению с 1м)
# * Total_Trans_Amt Общее количество трансакций за последние 12 месяцев
# * Total_Trans_Ct Общее число трансакций за последние 12 месяцев
# * Total_Ct_Chng_Q4_Q1 Изменение в количестве трансакциий (4 квартала по сравнению с 1м)
# * Avg_Utilization_Ratio Средний коэффициент использования карт (чем меньше, тем меньше кредитный риск)
# * Card_Category_Num Категория карты

# %%
#РАСЧЕТ ОСНОВНЫХ СТАТИСТИК ДАННЫХ, ВКЛЮЧАЯ МОДУ
metrics = df.describe()

mod = []

for col in df.columns:
    m = df[col].mode()[0]
    mod.append(m)
    
metrics.loc['moda'] = mod

metrics
# Out:
#        Customer_Age  Dependent_count  Months_on_book  \
# count  10127.000000     10127.000000    10127.000000
# mean      46.325960         2.346203       35.928409
# std        8.016814         1.298908        7.986416
# min       26.000000         0.000000       13.000000
# 25%       41.000000         1.000000       31.000000
# 50%       46.000000         2.000000       36.000000
# 75%       52.000000         3.000000       40.000000
# max       73.000000         5.000000       56.000000
# moda      44.000000         3.000000       36.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
# moda                   3.000000                3.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
# moda                3.000000  34516.000000             0.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
# moda       1438.300000              0.791000      4253.000000       81.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  Attrition_Flag_Num  \
# count         10127.000000           10127.000000        10127.000000
# mean              0.712222               0.274894            0.839340
# std               0.238086               0.275691            0.367235
# min               0.000000               0.000000            0.000000
# 25%               0.582000               0.023000            1.000000
# 50%               0.702000               0.176000            1.000000
# 75%               0.818000               0.503000            1.000000
# max               3.714000               0.999000            1.000000
# moda              0.667000               0.000000            1.000000
#
#          Gender_Num  Income_Category_Num  Marital_Status_Num  \
# count  10127.000000         10127.000000        10127.000000
# mean       0.529081             3.085711            3.241039
# std        0.499178             1.474639            0.880059
# min        0.000000             1.000000            1.000000
# 25%        0.000000             2.000000            3.000000
# 50%        1.000000             3.000000            3.000000
# 75%        1.000000             4.000000            4.000000
# max        1.000000             6.000000            4.000000
# moda       1.000000             2.000000            4.000000
#
#        Education_Level_Num  Card_Category_Num
# count         10127.000000       10127.000000
# mean              2.751950           1.083638
# std               1.496091           0.333784
# min               1.000000           1.000000
# 25%               1.000000           1.000000
# 50%               3.000000           1.000000
# 75%               4.000000           1.000000
# max               6.000000           4.000000
# moda              4.000000           1.000000

# %%
#ВИЗУАЛИЗАЦИЯ ПОКАЗАТЕЛЕЙ ПО СУЩЕСТВУЮЩИМ И ПОКИНУВШИМ КЛИЕНТАМ
for col in df.columns:    
    if col != 'Attrition_Flag_Num':
        sns.countplot(df[col],hue=df['Attrition_Flag_Num'])
        plt.show()

# %% [markdown]
# Визуально бросается в глаза, что у уходящих клиентов ниже показатели Total_Trans_ct, Total_Ct_Change Q4_Q1.

# %%
# КОРРЕЛЯЦИОННАЯ МАТРИЦА
np.round_(df.corr(), decimals=2)
# Out:
#                           Customer_Age  Dependent_count  Months_on_book  \
# Customer_Age                      1.00            -0.12            0.79
# Dependent_count                  -0.12             1.00           -0.10
# Months_on_book                    0.79            -0.10            1.00
# Total_Relationship_Count         -0.01            -0.04           -0.01
# Months_Inactive_12_mon            0.05            -0.01            0.07
# Contacts_Count_12_mon            -0.02            -0.04           -0.01
# Credit_Limit                      0.00             0.07            0.01
# Total_Revolving_Bal               0.01            -0.00            0.01
# Avg_Open_To_Buy                   0.00             0.07            0.01
# Total_Amt_Chng_Q4_Q1             -0.06            -0.04           -0.05
# Total_Trans_Amt                  -0.05             0.03           -0.04
# Total_Trans_Ct                   -0.07             0.05           -0.05
# Total_Ct_Chng_Q4_Q1              -0.01             0.01           -0.01
# Avg_Utilization_Ratio             0.01            -0.04           -0.01
# Attrition_Flag_Num               -0.02            -0.02           -0.01
# Gender_Num                        0.02            -0.00            0.01
# Income_Category_Num               0.02             0.07            0.02
# Marital_Status_Num                0.06            -0.02            0.04
# Education_Level_Num              -0.00             0.00            0.01
# Card_Category_Num                -0.02             0.03           -0.01
#
#                           Total_Relationship_Count  Months_Inactive_12_mon  \
# Customer_Age                                 -0.01                    0.05
# Dependent_count                              -0.04                   -0.01
# Months_on_book                               -0.01                    0.07
# Total_Relationship_Count                      1.00                   -0.00
# Months_Inactive_12_mon                       -0.00                    1.00
# Contacts_Count_12_mon                         0.06                    0.03
# Credit_Limit                                 -0.07                   -0.02
# Total_Revolving_Bal                           0.01                   -0.04
# Avg_Open_To_Buy                              -0.07                   -0.02
# Total_Amt_Chng_Q4_Q1                          0.05                   -0.03
# Total_Trans_Amt                              -0.35                   -0.04
# Total_Trans_Ct                               -0.24                   -0.04
# Total_Ct_Chng_Q4_Q1                           0.04                   -0.04
# Avg_Utilization_Ratio                         0.07                   -0.01
# Attrition_Flag_Num                            0.15                   -0.15
# Gender_Num                                   -0.00                    0.01
# Income_Category_Num                          -0.00                   -0.02
# Marital_Status_Num                            0.01                   -0.00
# Education_Level_Num                          -0.00                    0.00
# Card_Category_Num                            -0.09                   -0.01
#
#                           Contacts_Count_12_mon  Credit_Limit  \
# Customer_Age                              -0.02          0.00
# Dependent_count                           -0.04          0.07
# Months_on_book                            -0.01          0.01
# Total_Relationship_Count                   0.06         -0.07
# Months_Inactive_12_mon                     0.03         -0.02
# Contacts_Count_12_mon                      1.00          0.02
# Credit_Limit                               0.02          1.00
# Total_Revolving_Bal                       -0.05          0.04
# Avg_Open_To_Buy                            0.03          1.00
# Total_Amt_Chng_Q4_Q1                      -0.02          0.01
# Total_Trans_Amt                           -0.11          0.17
# Total_Trans_Ct                            -0.15          0.08
# Total_Ct_Chng_Q4_Q1                       -0.09         -0.00
# Avg_Utilization_Ratio                     -0.06         -0.48
# Attrition_Flag_Num                        -0.20          0.02
# Gender_Num                                -0.04         -0.42
# Income_Category_Num                        0.02          0.48
# Marital_Status_Num                         0.01         -0.05
# Education_Level_Num                       -0.01         -0.00
# Card_Category_Num                         -0.00          0.49
#
#                           Total_Revolving_Bal  Avg_Open_To_Buy  \
# Customer_Age                             0.01             0.00
# Dependent_count                         -0.00             0.07
# Months_on_book                           0.01             0.01
# Total_Relationship_Count                 0.01            -0.07
# Months_Inactive_12_mon                  -0.04            -0.02
# Contacts_Count_12_mon                   -0.05             0.03
# Credit_Limit                             0.04             1.00
# Total_Revolving_Bal                      1.00            -0.05
# Avg_Open_To_Buy                         -0.05             1.00
# Total_Amt_Chng_Q4_Q1                     0.06             0.01
# Total_Trans_Amt                          0.06             0.17
# Total_Trans_Ct                           0.06             0.07
# Total_Ct_Chng_Q4_Q1                      0.09            -0.01
# Avg_Utilization_Ratio                    0.62            -0.54
# Attrition_Flag_Num                       0.26             0.00
# Gender_Num                              -0.03            -0.42
# Income_Category_Num                      0.03             0.47
# Marital_Status_Num                       0.02            -0.06
# Education_Level_Num                     -0.01            -0.00
# Card_Category_Num                        0.03             0.49
#
#                           Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# Customer_Age                             -0.06            -0.05
# Dependent_count                          -0.04             0.03
# Months_on_book                           -0.05            -0.04
# Total_Relationship_Count                  0.05            -0.35
# Months_Inactive_12_mon                   -0.03            -0.04
# Contacts_Count_12_mon                    -0.02            -0.11
# Credit_Limit                              0.01             0.17
# Total_Revolving_Bal                       0.06             0.06
# Avg_Open_To_Buy                           0.01             0.17
# Total_Amt_Chng_Q4_Q1                      1.00             0.04
# Total_Trans_Amt                           0.04             1.00
# Total_Trans_Ct                            0.01             0.81
# Total_Ct_Chng_Q4_Q1                       0.38             0.09
# Avg_Utilization_Ratio                     0.04            -0.08
# Attrition_Flag_Num                        0.13             0.17
# Gender_Num                               -0.03            -0.02
# Income_Category_Num                       0.01             0.02
# Marital_Status_Num                        0.04            -0.05
# Education_Level_Num                      -0.01            -0.01
# Card_Category_Num                         0.01             0.20
#
#                           Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# Customer_Age                       -0.07                -0.01
# Dependent_count                     0.05                 0.01
# Months_on_book                     -0.05                -0.01
# Total_Relationship_Count           -0.24                 0.04
# Months_Inactive_12_mon             -0.04                -0.04
# Contacts_Count_12_mon              -0.15                -0.09
# Credit_Limit                        0.08                -0.00
# Total_Revolving_Bal                 0.06                 0.09
# Avg_Open_To_Buy                     0.07                -0.01
# Total_Amt_Chng_Q4_Q1                0.01                 0.38
# Total_Trans_Amt                     0.81                 0.09
# Total_Trans_Ct                      1.00                 0.11
# Total_Ct_Chng_Q4_Q1                 0.11                 1.00
# Avg_Utilization_Ratio               0.00                 0.07
# Attrition_Flag_Num                  0.37                 0.29
# Gender_Num                          0.07                 0.01
# Income_Category_Num                -0.05                -0.01
# Marital_Status_Num                 -0.09                 0.01
# Education_Level_Num                -0.01                -0.02
# Card_Category_Num                   0.13                -0.01
#
#                           Avg_Utilization_Ratio  Attrition_Flag_Num  \
# Customer_Age                               0.01               -0.02
# Dependent_count                           -0.04               -0.02
# Months_on_book                            -0.01               -0.01
# Total_Relationship_Count                   0.07                0.15
# Months_Inactive_12_mon                    -0.01               -0.15
# Contacts_Count_12_mon                     -0.06               -0.20
# Credit_Limit                              -0.48                0.02
# Total_Revolving_Bal                        0.62                0.26
# Avg_Open_To_Buy                           -0.54                0.00
# Total_Amt_Chng_Q4_Q1                       0.04                0.13
# Total_Trans_Amt                           -0.08                0.17
# Total_Trans_Ct                             0.00                0.37
# Total_Ct_Chng_Q4_Q1                        0.07                0.29
# Avg_Utilization_Ratio                      1.00                0.18
# Attrition_Flag_Num                         0.18                1.00
# Gender_Num                                 0.26               -0.04
# Income_Category_Num                       -0.25                0.01
# Marital_Status_Num                         0.05                0.02
# Education_Level_Num                       -0.00               -0.01
# Card_Category_Num                         -0.20               -0.00
#
#                           Gender_Num  Income_Category_Num  Marital_Status_Num  \
# Customer_Age                    0.02                 0.02                0.06
# Dependent_count                -0.00                 0.07               -0.02
# Months_on_book                  0.01                 0.02                0.04
# Total_Relationship_Count       -0.00                -0.00                0.01
# Months_Inactive_12_mon          0.01                -0.02               -0.00
# Contacts_Count_12_mon          -0.04                 0.02                0.01
# Credit_Limit                   -0.42                 0.48               -0.05
# Total_Revolving_Bal            -0.03                 0.03                0.02
# Avg_Open_To_Buy                -0.42                 0.47               -0.06
# Total_Amt_Chng_Q4_Q1           -0.03                 0.01                0.04
# Total_Trans_Amt                -0.02                 0.02               -0.05
# Total_Trans_Ct                  0.07                -0.05               -0.09
# Total_Ct_Chng_Q4_Q1             0.01                -0.01                0.01
# Avg_Utilization_Ratio           0.26                -0.25                0.05
# Attrition_Flag_Num             -0.04                 0.01                0.02
# Gender_Num                      1.00                -0.79               -0.00
# Income_Category_Num            -0.79                 1.00                0.01
# Marital_Status_Num             -0.00                 0.01                1.00
# Education_Level_Num             0.01                -0.01                0.01
# Card_Category_Num              -0.08                 0.08               -0.04
#
#                           Education_Level_Num  Card_Category_Num
# Customer_Age                            -0.00              -0.02
# Dependent_count                          0.00               0.03
# Months_on_book                           0.01              -0.01
# Total_Relationship_Count                -0.00              -0.09
# Months_Inactive_12_mon                   0.00              -0.01
# Contacts_Count_12_mon                   -0.01              -0.00
# Credit_Limit                            -0.00               0.49
# Total_Revolving_Bal                     -0.01               0.03
# Avg_Open_To_Buy                         -0.00               0.49
# Total_Amt_Chng_Q4_Q1                    -0.01               0.01
# Total_Trans_Amt                         -0.01               0.20
# Total_Trans_Ct                          -0.01               0.13
# Total_Ct_Chng_Q4_Q1                     -0.02              -0.01
# Avg_Utilization_Ratio                   -0.00              -0.20
# Attrition_Flag_Num                      -0.01              -0.00
# Gender_Num                               0.01              -0.08
# Income_Category_Num                     -0.01               0.08
# Marital_Status_Num                       0.01              -0.04
# Education_Level_Num                      1.00               0.02
# Card_Category_Num                        0.02               1.00

# %%
# ВИЗУАЛИЗАЦИЯ КОРРЕЛЯЦИОННОЙ МАТРИЦЫ
sns.heatmap(df.corr(),annot=True,cmap='GnBu',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.title('График 1. "Тепловая" карта корреляционной матрицы')
plt.show()

# %% [markdown]
# Корреляционная матрица наглядно показывает взаимосвязи между такими параметрами, как:
# *  Avg_Open_To_Buy 	и Credit_Limit. Проанализировав данные, можно увидеть, что  Credit_Limit рассчитывается, как  Total_Revolving_Bal + Avg_Open_To_Buy, т.е. расчет этих показателей взаимосвязан.
# * Total_Revolving_Bal и Avg_Utilization_Ratio. Можно увидеть, что  Avg_Utilization_Ratio рассчитывается как Total_Revolving_Bal/Credit_Limit, поэтому наблюдается высокий коэффициент корреляции.
# * Customer_Age и Months_on_book. Интересная взаимосвязь, говорящая о том, что чем старше человек, тем больше его длительность обслуживания в банке, при этом средний возраст клиента- 46 лет, а средняя длительность обслуживания - 3 года.

# %%
# КОРРЕЛЯЦИЯ ДАННЫХ С ЦЕЛЕВОЙ ПЕРЕМЕННОЙ
np.round_(df.corr(), decimals=2)['Attrition_Flag_Num'].sort_values().reset_index()
# Out:
#                        index  Attrition_Flag_Num
# 0      Contacts_Count_12_mon               -0.20
# 1     Months_Inactive_12_mon               -0.15
# 2                 Gender_Num               -0.04
# 3               Customer_Age               -0.02
# 4            Dependent_count               -0.02
# 5             Months_on_book               -0.01
# 6        Education_Level_Num               -0.01
# 7            Avg_Open_To_Buy                0.00
# 8          Card_Category_Num               -0.00
# 9        Income_Category_Num                0.01
# 10              Credit_Limit                0.02
# 11        Marital_Status_Num                0.02
# 12      Total_Amt_Chng_Q4_Q1                0.13
# 13  Total_Relationship_Count                0.15
# 14           Total_Trans_Amt                0.17
# 15     Avg_Utilization_Ratio                0.18
# 16       Total_Revolving_Bal                0.26
# 17       Total_Ct_Chng_Q4_Q1                0.29
# 18            Total_Trans_Ct                0.37
# 19        Attrition_Flag_Num                1.00

# %% [markdown]
# Анализ корреляции не позволяет в данном исследовании выявить значимые факторы, влияющие на целевую переменную.

# %%
#ГРАФИКИ РАСПРЕДЕЛЕНИЯ ПАРАМЕТРОВ МОДЕЛИ

i = 1

for x in df.columns:
    fig = plt.figure()  
    fig.set_size_inches(5, 4) 
    df[x].hist()

    i = i+1
    
    plt.title(f'График {i}. Распределение {x}')
    plt.show()

# %% [markdown]
# По графикам распределения параметров можно сделать следующие выводы:
# * нормальное распределение можно выявить у показателей Customer Age, Dependent Count, Months on Book, Contracts Count 12 mon, Total Amount Chng Q4 Q1, Total Ct Chng Q4 Q1, Total Trans Ct
# * экспоненциальное -Credit limit, Av Open to buy,  Avg Utilization Ratio
# * геометрическое - Card Category Num
# * распределение Бернулли Attrition_Flag_Num, Gender_Num
# * также надо оговориться, что анализ графика Marital_Status_Num может привести к некорректным выводам, так как категориальные данные переведены в числовые без математической основы.

# %% [markdown]
# ## 3. Построение предсказательной модели

# %%
# ОПРЕДЕЛЕНИЕ НЕЗАВИСИМЫХ И ЗАВИСИМОЙ ПЕРЕМЕННЫХ
X, y = df.drop('Attrition_Flag_Num', axis=1), df['Attrition_Flag_Num']

# %%
# РАЗДЕЛЕНИЕ ВЫБОРОК НА ОБУЧАЮЩУЮ И ТЕСТОВУЮ
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
# ПОСТРОЕНИЕ МОДЕЛИ ЛОГИСТИЧЕСКОЙ РЕГРЕССИИ, ВКЛЮЧАЮЩУЮ СТАНДАРТИЗАЦИЮ ДАННЫХ
pipe1 = Pipeline([('scaler', StandardScaler()), ('log', LogisticRegression(C = 50))])
pipe1.fit(X_train, Y_train) #https://habr.com/ru/company/plarium/blog/512332/
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('log', LogisticRegression(C=50))])

# %%
# ВЫВОД ОЦЕНОК МОДЕЛИ
print(classification_report(Y_test, pipe.predict(X_test)))
print('roc_auc_score', roc_auc_score(Y_test, pipe1.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.78       333
#            1       0.94      0.98      0.96      1693
#
#     accuracy                           0.93      2026
#    macro avg       0.91      0.84      0.87      2026
# weighted avg       0.93      0.93      0.93      2026
#
# roc_auc_score 0.7741619351188164

# %%
#ОПТИМИЗАЦИЯ ПАРАМЕТРОВ  МОДЕЛИ ЛОГИСТИЧЕСКОЙ РЕГРЕССИИ
searchCV = LogisticRegressionCV(
    Cs=list(np.power(10.0, np.arange(-10, 10)))
    ,penalty='l2'
    ,scoring='roc_auc'
    ,random_state=777
    ,max_iter=10000
    ,fit_intercept=True
    ,solver='newton-cg'
    ,tol=10
)
searchCV.fit(X_train, Y_train)
# Out:
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:466: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# C:\Users\ukras\anaconda3\lib\site-packages\scipy\optimize\linesearch.py:314: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# LogisticRegressionCV(Cs=[1e-10, 1e-09, 1e-08, 1e-07, 1e-06, 1e-05, 0.0001,
#                          0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0,
#                          100000.0, 1000000.0, 10000000.0, 100000000.0,
#                          1000000000.0],
#                      max_iter=10000, random_state=777, scoring='roc_auc',
#                      solver='newton-cg', tol=10)

# %%
# ВЫВОД ОЦЕНОК  ОПТИМИЗИРОВАННОЙ МОДЕЛИ МОДЕЛИ ЛОГИСТИЧЕСКОЙ РЕГРЕССИИ
print(classification_report(Y_test, searchCV.predict(X_test)))
print('roc_auc_score', roc_auc_score(Y_test, searchCV.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.56      0.65       333
#            1       0.92      0.97      0.94      1693
#
#     accuracy                           0.90      2026
#    macro avg       0.84      0.76      0.79      2026
# weighted avg       0.89      0.90      0.89      2026
#
# roc_auc_score 0.7633560908811944

# %% [markdown]
# ??? ПОЧЕМУ ОНИ У МЕНЯ ХУЖЕ?)

# %%
# ПОСТРОЕНИЕ МОДЕЛИ RANDOM FOREST CLASSIFIER, ВКЛЮЧАЮЩУЮ СТАНДАРТИЗАЦИЮ ДАННЫХ
pipe2 = Pipeline([('scaler', StandardScaler()), ('rfc',RandomForestClassifier())])
pipe2.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rfc', RandomForestClassifier())])

# %%
# ВЫВОД ОЦЕНОК МОДЕЛИ RANDOM FOREST CLASSIFIER
print(classification_report(Y_test, pipe2.predict(X_test)))
print('roc_auc_score', roc_auc_score(Y_test, pipe2.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88       333
#            1       0.97      0.99      0.98      1693
#
#     accuracy                           0.96      2026
#    macro avg       0.95      0.91      0.93      2026
# weighted avg       0.96      0.96      0.96      2026
#
# roc_auc_score 0.9097139076465716

# %%
#ОПТИМИЗАЦИЯ МОДЕЛИ RANDOM FOREST CLASSIFIER
parametrs = { 'n_estimators': range (10, 51, 10),
              'max_depth': range (1,13, 2),
              'min_samples_leaf': range (1,8),
              'min_samples_split': range (2,10,2) }
grid1 = GridSearchCV(pipe2, parametrs, cv=5)
grid1.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-fd048356f6e6> in <module>
#       5               'min_samples_split': range (2,10,2) }
#       6 grid = GridSearchCV(pipe2, parametrs, cv=5)
# ----> 7 grid.fit(X_train, Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     807                                    (split_idx, (train, test)) in product(
#     808                                    enumerate(candidate_params),
# --> 809                                    enumerate(cv.split(X, y, groups))))
#     810
#     811                 if len(out) < 1:
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     579             cloned_parameters[k] = clone(v, safe=False)
#     580
# --> 581         estimator = estimator.set_params(**cloned_parameters)
#     582
#     583     start_time = time.time()
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in set_params(self, **kwargs)
#     148         self
#     149         """
# --> 150         self._set_params('steps', **kwargs)
#     151         return self
#     152
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in _set_params(self, attr, **params)
#      52                 self._replace_estimator(attr, name, params.pop(name))
#      53         # 3. Step parameters and other initialisation arguments
# ---> 54         super().set_params(**params)
#      55         return self
#      56
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in set_params(self, **params)
#     231                                  'Check the list of available parameters '
#     232                                  'with `estimator.get_params().keys()`.' %
# --> 233                                  (key, self))
#     234
#     235             if delim:
#
# ValueError: Invalid parameter max_depth for estimator Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rfc', RandomForestClassifier())]). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
# ВЫВОД ОЦЕНОК МОДЕЛИ RANDOM FOREST CLASSIFIER
print(classification_report(Y_test, grid1.predict(X_test)))
print('roc_auc_score', roc_auc_score(Y_test, grid1.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.78      0.85       333
#            1       0.96      0.99      0.97      1693
#
#     accuracy                           0.96      2026
#    macro avg       0.95      0.88      0.91      2026
# weighted avg       0.96      0.96      0.95      2026
#
# roc_auc_score 0.8847542167093259

# %%
# ПОСТРОЕНИЕ МОДЕЛИ SUPPORT VECTOR CLASSIFICATION, ВКЛЮЧАЮЩУЮ СТАНДАРТИЗАЦИЮ ДАННЫХ
pipe3 = Pipeline([('scaler', StandardScaler()), ('svc',SVC(gamma='auto'))])
pipe3.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC(gamma='auto'))])

# %%
# ВЫВОД ОЦЕНОК МОДЕЛИ SUPPORT VECTOR CLASSIFICATION
print(classification_report(Y_test, pipe3.predict(X_test)))
print('roc_auc_score', roc_auc_score(Y_test, pipe3.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.78       333
#            1       0.94      0.98      0.96      1693
#
#     accuracy                           0.93      2026
#    macro avg       0.91      0.84      0.87      2026
# weighted avg       0.93      0.93      0.93      2026
#
# roc_auc_score 0.8395131694009424

# %%
parametrs = {'C':[1,10,100,1000],'gamma':[1,0.1,0.001,0.0001], 'kernel':['linear','rbf']}
grid2 = GridSearchCV(pipe3, parametrs, cv=5)
grid2.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-aa33c603a92b> in <module>
#       1 parametrs = {'C':[1,10,100,1000],'gamma':[1,0.1,0.001,0.0001], 'kernel':['linear','rbf']}
#       2 grid2 = GridSearchCV(pipe3, parametrs, cv=5)
# ----> 3 grid2.fit(X_train, Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     807                                    (split_idx, (train, test)) in product(
#     808                                    enumerate(candidate_params),
# --> 809                                    enumerate(cv.split(X, y, groups))))
#     810
#     811                 if len(out) < 1:
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     579             cloned_parameters[k] = clone(v, safe=False)
#     580
# --> 581         estimator = estimator.set_params(**cloned_parameters)
#     582
#     583     start_time = time.time()
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in set_params(self, **kwargs)
#     148         self
#     149         """
# --> 150         self._set_params('steps', **kwargs)
#     151         return self
#     152
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in _set_params(self, attr, **params)
#      52                 self._replace_estimator(attr, name, params.pop(name))
#      53         # 3. Step parameters and other initialisation arguments
# ---> 54         super().set_params(**params)
#      55         return self
#      56
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in set_params(self, **params)
#     231                                  'Check the list of available parameters '
#     232                                  'with `estimator.get_params().keys()`.' %
# --> 233                                  (key, self))
#     234
#     235             if delim:
#
# ValueError: Invalid parameter C for estimator Pipeline(steps=[('scaler', StandardScaler()), ('svc', SVC(gamma='auto'))]). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
# ВЫВОД ОЦЕНОК ОПТИМИЗИРОВАННОЙ МОДЕЛИ SUPPORT VECTOR CLASSIFICATION
print(classification_report(Y_test, grid2.predict(X_test)))
print('roc_auc_score', roc_auc_score(Y_test, grid2.predict(X_test)))

# %%
#РАСЧЕТ МАТРИЦЫ ОШИБОК
result = pd.DataFrame([Y_test.values, searchCV.predict(X_test)]).T
confusion_matrix = pd.crosstab(result[0], result[1], rownames=['Actual'], colnames=['Predicted'])
confusion_matrix
# Out:
# Predicted    0     1
# Actual
# 0          187   146
# 1           59  1634

# %%
# ОПРЕДЕЛЕНИЕ ЗНАЧИМЫХ ПАРАМЕТРОВ

features = ['Customer_Age', 'Dependent_count', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
        'Gender_Num', 'Income_Category_Num',
       'Marital_Status_Num', 'Education_Level_Num', 'Card_Category_Num']

importance = searchCV.coef_[0]


feature_importance = pd.DataFrame(features, columns = ['Feature'])

feature_importance['Score'] = importance
feature_importance['Score_modul'] = abs(importance)
feature_importance= feature_importance.sort_values(by=['Score_modul'])
feature_importance
# Out:
#                      Feature     Score  Score_modul
# 0               Customer_Age  0.000181     0.000181
# 8            Avg_Open_To_Buy -0.000314     0.000314
# 6               Credit_Limit  0.000327     0.000327
# 10           Total_Trans_Amt -0.000471     0.000471
# 7        Total_Revolving_Bal  0.000641     0.000641
# 2             Months_on_book  0.007092     0.007092
# 13     Avg_Utilization_Ratio -0.015781     0.015781
# 17       Education_Level_Num -0.020427     0.020427
# 11            Total_Trans_Ct  0.115211     0.115211
# 1            Dependent_count -0.145679     0.145679
# 15       Income_Category_Num -0.182813     0.182813
# 16        Marital_Status_Num  0.223514     0.223514
# 3   Total_Relationship_Count  0.427097     0.427097
# 18         Card_Category_Num -0.431395     0.431395
# 9       Total_Amt_Chng_Q4_Q1  0.476889     0.476889
# 4     Months_Inactive_12_mon -0.494666     0.494666
# 5      Contacts_Count_12_mon -0.520741     0.520741
# 14                Gender_Num -1.014736     1.014736
# 12       Total_Ct_Chng_Q4_Q1  2.444884     2.444884
