# %% [markdown]
# # Домашнее задание к лекции "Базовые понятия статистики"

# %% [markdown]
# ## Обязательная часть
#
# Будем осуществлять работу с непростым [набором данных](https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/statistics_basics/horse_data.csv) о состоянии здоровья лошадей, испытывающих кишечные колики.
#
# ### Задание 1. Базовое изучение
#
# Изучить представленный набор данных на основе [описания его столбцов](https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/statistics_basics/horse_data.names) и выбрать 8 столбцов для дальнейшего изучения (среди них должны быть как числовые, так и категориальные). Провести расчет базовых метрик для них, кратко описать результаты.
#
# ### Задание 2. Работа с выбросами
#
# В выбранных числовых столбцах найти выбросы, выдвинуть гипотезы об их причинах и проинтерпретировать результаты. Принять и обосновать решение о дальнейшей работе с ними.
#
# ### Задание 3. Работа с пропусками
#
# Рассчитать количество пропусков для всех выбранных столбцов. Принять и обосновать решение о методе работы с пропусками по каждому столбцу, сформировать датафрейм, в котором пропуски будут отсутствовать.

# %% [markdown]
# ## Дополнительная часть (необязательная)
#
# Выполнить задания 1-3 для всего набора данных.

# %% [markdown]
# # Обязательная часть
#
# ## Задание 1. Базовое изучение

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df =  pd.read_csv('horse_data.txt', names = ['surgery', 'age', 'hosp_no', 'rect_temp', 'pulse', 'resp_rate','extrem_temp', 'per_pulse', 'muc_memr', 'cap_refill', 'pain', 'peristalsis', 'abd_distension', 'nas_tube', 'nas_reflux','nas_refluxPH', 'rect-examination', 'abdomen', 'cell_volume', 'total_protein', 'abd_appearance', 'abd_total_protein', 'outcome', 'surgical_lesion', 'lesion1', 'lesion2', 'lesion3', 'cp_data'])

# %%
df.head()
# Out:
#   surgery  age  hosp_no rect_temp pulse resp_rate extrem_temp per_pulse  \
# 0       2    1   530101     38.50    66        28           3         3
# 1       1    1   534817      39.2    88        20           ?         ?
# 2       2    1   530334     38.30    40        24           1         1
# 3       1    9  5290409     39.10   164        84           4         1
# 4       2    1   530255     37.30   104        35           ?         ?
#
#   muc_memr cap_refill  ... cell_volume total_protein abd_appearance  \
# 0        ?          2  ...       45.00          8.40              ?
# 1        4          1  ...          50            85              2
# 2        3          1  ...       33.00          6.70              ?
# 3        6          2  ...       48.00          7.20              3
# 4        6          2  ...       74.00          7.40              ?
#
#   abd_total_protein outcome surgical_lesion lesion1 lesion2 lesion3 cp_data
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   surgery            300 non-null    object
#  1   age                300 non-null    int64
#  2   hosp_no            300 non-null    int64
#  3   rect_temp          300 non-null    object
#  4   pulse              300 non-null    object
#  5   resp_rate          300 non-null    object
#  6   extrem_temp        300 non-null    object
#  7   per_pulse          300 non-null    object
#  8   muc_memr           300 non-null    object
#  9   cap_refill         300 non-null    object
#  10  pain               300 non-null    object
#  11  peristalsis        300 non-null    object
#  12  abd_distension     300 non-null    object
#  13  nas_tube           300 non-null    object
#  14  nas_reflux         300 non-null    object
#  15  nas_refluxPH       300 non-null    object
# ...

# %%
df.replace('?', 'NaN', inplace=True)

# %%
df = df.astype('float')

# %%
df.describe()
# Out:
#           surgery         age       hosp_no   rect_temp       pulse  \
# count  299.000000  300.000000  3.000000e+02  240.000000  276.000000
# mean     1.397993    1.640000  1.085889e+06   38.167917   71.913043
# std      0.490305    2.173972  1.529801e+06    0.732289   28.630557
# min      1.000000    1.000000  5.184760e+05   35.400000   30.000000
# 25%      1.000000    1.000000  5.289040e+05   37.800000   48.000000
# 50%      1.000000    1.000000  5.303055e+05   38.200000   64.000000
# 75%      2.000000    1.000000  5.347275e+05   38.500000   88.000000
# max      2.000000    9.000000  5.305629e+06   40.800000  184.000000
#
#         resp_rate  extrem_temp   per_pulse    muc_memr  cap_refill  ...  \
# count  242.000000   244.000000  231.000000  253.000000  268.000000  ...
# mean    30.417355     2.348361    2.017316    2.853755    1.305970  ...
# std     17.642231     1.045054    1.042428    1.620294    0.477629  ...
# ...

# %%
df_dz1 = df[['surgery', 'age', 'rect_temp', 'pulse', 'pain','abd_appearance', 'total_protein', 'outcome']]

# %%
df_dz1.head()
# Out:
#    surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 0      2.0  1.0       38.5   66.0   5.0             NaN            8.4
# 1      1.0  1.0       39.2   88.0   3.0             2.0           85.0
# 2      2.0  1.0       38.3   40.0   3.0             NaN            6.7
# 3      1.0  9.0       39.1  164.0   2.0             3.0            7.2
# 4      2.0  1.0       37.3  104.0   NaN             NaN            7.4
#
#    outcome
# 0      2.0
# 1      3.0
# 2      1.0
# 3      2.0
# 4      2.0

# %%
metrics = df_dz1.describe()

# %%
mod = []

for col in df_dz1.columns:
    m = df_dz1[col].mode()[0]
    mod.append(m)

# %%
mod
# Out:
# [1.0, 1.0, 38.0, 48.0, 3.0, 2.0, 6.5, 1.0]

# %%
metrics.loc['moda'] = mod

# %%
metrics.loc['rang'] = metrics.loc['max'] - metrics.loc['min']

# %%
metrics.loc['lower_bound'] = metrics.loc['25%'] - (1.5 * ( metrics.loc['75%'] - metrics.loc['25%']))

# %%
metrics.loc['upper_bound'] = metrics.loc['75%'] + (1.5 * ( metrics.loc['75%'] - metrics.loc['25%']))

# %%
metrics
# Out:
#                 surgery         age   rect_temp       pulse       pain  \
# count        299.000000  300.000000  240.000000  276.000000  245.00000
# mean           1.397993    1.640000   38.167917   71.913043    2.95102
# std            0.490305    2.173972    0.732289   28.630557    1.30794
# min            1.000000    1.000000   35.400000   30.000000    1.00000
# 25%            1.000000    1.000000   37.800000   48.000000    2.00000
# 50%            1.000000    1.000000   38.200000   64.000000    3.00000
# 75%            2.000000    1.000000   38.500000   88.000000    4.00000
# max            2.000000    9.000000   40.800000  184.000000    5.00000
# moda           1.000000    1.000000   38.000000   48.000000    3.00000
# rang           1.000000    8.000000    5.400000  154.000000    4.00000
# lower_bound   -0.500000    1.000000   36.750000  -12.000000   -1.00000
# upper_bound    3.500000    1.000000   39.550000  148.000000    7.00000
#
# ...

# %%
df_dz1.sort_values("pulse").head(100)
# Out:
#      surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 232      1.0  1.0       38.5   30.0   NaN             NaN            7.7
# 130      1.0  1.0       37.8   30.0   NaN             NaN            NaN
# 242      1.0  1.0        NaN   36.0   5.0             NaN            5.9
# 203      2.0  1.0       37.2   36.0   2.0             NaN            5.7
# 276      1.0  1.0       38.0   36.0   4.0             2.0           75.0
# ..       ...  ...        ...    ...   ...             ...            ...
# 67       2.0  1.0       38.4   54.0   1.0             1.0            7.2
# 284      2.0  1.0       38.5   54.0   3.0             2.0            6.8
# 267      2.0  1.0       38.3   54.0   2.0             3.0            7.2
# 85       2.0  1.0       38.0   54.0   3.0             NaN            6.2
# 237      2.0  1.0       37.9   54.0   3.0             3.0           54.0
#
#      outcome
# 232      1.0
# 130      2.0
# 242      2.0
# 203      1.0
# 276      3.0
# ...

# %% [markdown]
# ## Выводы

# %% [markdown]
# ## Задание 2. Работа с выбросами
# В выбранных числовых столбцах найти выбросы, выдвинуть гипотезы об их причинах и проинтерпретировать результаты. Принять и обосновать решение о дальнейшей работе с ними.

# %%
 for col in metrics.columns:
        if metrics[col].loc['min'] < metrics[col].loc['lower_bound'] or metrics[col].loc['max'] > metrics[col].loc['upper_bound']:
            print(f'{col} - выбросы есть' )
# Out:
# age - выбросы есть
# rect_temp - выбросы есть
# pulse - выбросы есть

# %%
df_dz1[df_dz1.age > 1]
# Out:
#      surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 3        1.0  9.0       39.1  164.0   2.0             3.0            7.2
# 9        2.0  9.0       38.3   90.0   5.0             1.0            6.2
# 13       2.0  9.0       38.0   92.0   1.0             1.0            6.1
# 16       1.0  9.0        NaN  128.0   4.0             3.0            7.8
# 23       1.0  9.0       38.3  130.0   2.0             NaN           70.0
# 39       1.0  9.0       39.2  146.0   NaN             NaN            NaN
# 41       2.0  9.0       39.0  150.0   NaN             NaN            8.5
# 55       1.0  9.0       38.6  160.0   3.0             2.0            NaN
# 74       1.0  9.0        NaN    NaN   NaN             NaN            4.9
# 75       1.0  9.0       39.7  100.0   2.0             2.0           57.0
# 82       1.0  9.0       38.1  100.0   3.0             NaN            5.7
# 103      1.0  9.0       38.0  140.0   3.0             NaN            5.3
# ...

# %%
df_dz1.age.value_counts()
# Out:
# 1.0    276
# 9.0     24
# Name: age, dtype: int64

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df_dz1['age'].replace(9, np.NaN, inplace=True)

# %%
df_dz1.head(25)
# Out:
#     surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 0       2.0  1.0       38.5   66.0   5.0             NaN            8.4
# 1       1.0  1.0       39.2   88.0   3.0             2.0           85.0
# 2       2.0  1.0       38.3   40.0   3.0             NaN            6.7
# 3       1.0  NaN       39.1  164.0   2.0             3.0            7.2
# 4       2.0  1.0       37.3  104.0   NaN             NaN            7.4
# 5       2.0  1.0        NaN    NaN   2.0             NaN            NaN
# 6       1.0  1.0       37.9   48.0   3.0             NaN            7.0
# 7       1.0  1.0        NaN   60.0   NaN             NaN            8.3
# 8       2.0  1.0        NaN   80.0   4.0             NaN            6.2
# 9       2.0  NaN       38.3   90.0   5.0             1.0            6.2
# 10      1.0  1.0       38.1   66.0   3.0             2.0            6.0
# 11      2.0  1.0       39.1   72.0   2.0             NaN            7.8
# ...

# %% [markdown]
# #### Столбец Age выбросы выводы:
# Согласно описанию в этом столбце возможны только значения:  1 = Adult horse 2 = Young (< 6 months). Однако в данных есть только значения 1 и 9. У нас нет доказательств, чтобы допустить, что 9 это 2. В то же время значения 9 оставляют 8 % данных, что является значительным для их удаления. Решение : заменить 9 на NaN.

# %%
df_dz1.rect_temp.value_counts().sort_index()
# Out:
# 35.4     1
# 36.0     1
# 36.1     1
# 36.4     1
# 36.5     2
# 36.6     1
# 36.8     1
# 36.9     1
# 37.0     2
# 37.1     3
# 37.2     7
# 37.3     6
# 37.4     3
# 37.5    12
# 37.6     7
# 37.7     7
# 37.8    17
# 37.9     7
# 38.0    26
# 38.1    12
# 38.2    16
# 38.3    18
# 38.4    11
# 38.5    19
# 38.6    12
# 38.7     7
# 38.8     6
# 38.9     4
# 39.0     4
# 39.1     2
# 39.2     5
# 39.3     4
# 39.4     3
# 39.5     4
# 39.6     1
# 39.7     1
# 39.9     1
# 40.0     1
# 40.3     2
# 40.8     1
# Name: rect_temp, dtype: int64

# %%
df_dz1.pulse.value_counts().sort_index()
# Out:
# 30.0      2
# 36.0      3
# 38.0      1
# 40.0     18
# 42.0     10
# 44.0     11
# 45.0      2
# 46.0      1
# 48.0     28
# 49.0      1
# 50.0      6
# 52.0     12
# 54.0      7
# 56.0      7
# 60.0     25
# 64.0      8
# 65.0      1
# 66.0      6
# 68.0      5
# 70.0      4
# 72.0     11
# 75.0      1
# 76.0      4
# 78.0      3
# 80.0      8
# 82.0      1
# 84.0      8
# 86.0      3
# 88.0     12
# 90.0      3
# 92.0      4
# 96.0      8
# 98.0      1
# 100.0    11
# 104.0     5
# 108.0     3
# 110.0     1
# 112.0     3
# 114.0     2
# 120.0    10
# 124.0     2
# 128.0     1
# 129.0     1
# 130.0     2
# 132.0     1
# 136.0     1
# 140.0     2
# 146.0     1
# 150.0     2
# 160.0     1
# 164.0     1
# 184.0     1
# Name: pulse, dtype: int64

# %% [markdown]
# #### Столбцы rect_temp и pulse выбросы выводы:
# Выбросы распределены внешне равномерно и не выглядят аномально, поэтому считаю важным для анализа их оставить.

# %% [markdown]
# ### Задание 3. Работа с пропусками
#
# Рассчитать количество пропусков для всех выбранных столбцов. Принять и обосновать решение о методе работы с пропусками по каждому столбцу, сформировать датафрейм, в котором пропуски будут отсутствовать.

# %%
for col in df_dz1.columns:
    missing = df_dz1[col].isna().sum()
    print(f'{col} - {missing}')
# Out:
# surgery - 1
# age - 24
# rect_temp - 60
# pulse - 24
# pain - 55
# abd_appearance - 165
# total_protein - 33
# outcome - 1

# %%
for col in df_dz1.columns:
    pct_missing = df_dz1[col].isnull().mean()
    print(f'{col} - {pct_missing :.1%}')
# Out:
# surgery - 0.3%
# age - 8.0%
# rect_temp - 20.0%
# pulse - 8.0%
# pain - 18.3%
# abd_appearance - 55.0%
# total_protein - 11.0%
# outcome - 0.3%

# %%
df_dz1[df_dz1['surgery'].isnull()]
# Out:
#      surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 132      NaN  1.0       38.0   48.0   4.0             2.0           73.0
#
#      outcome
# 132      NaN

# %% [markdown]
# #### Пропуски surgery и outcome.
# В этой строке нет 2 важных для данного датафрейма параметров: операция и результат. Т.к. это логические параметры, постановка средних значений  и наиболее часто встречающихся параметров может быть некорректно. Предлагаю удалить эту строку.

# %%
df_dz1.drop(132, inplace=True)

# %%
df_dz1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   surgery         299 non-null    float64
#  1   age             275 non-null    float64
#  2   rect_temp       239 non-null    float64
#  3   pulse           275 non-null    float64
#  4   pain            244 non-null    float64
#  5   abd_appearance  134 non-null    float64
#  6   total_protein   266 non-null    float64
#  7   outcome         299 non-null    float64
# dtypes: float64(8)
# memory usage: 21.0 KB

# %% [markdown]
# #### Пропуски Age
#  Здесь пропуски появились в результате преобразования некорретных данных и замена их на другие приведет к дальнейшему искажению, поэтому предлагаю их проигноприровать.

# %%
df_dz1[df_dz1['rect_temp'].isnull()]
# Out:
#      surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 5        2.0  1.0        NaN    NaN   2.0             NaN            NaN
# 7        1.0  1.0        NaN   60.0   NaN             NaN            8.3
# 8        2.0  1.0        NaN   80.0   4.0             NaN            6.2
# 16       1.0  NaN        NaN  128.0   4.0             3.0            7.8
# 28       1.0  1.0        NaN    NaN   NaN             NaN            NaN
# 34       1.0  1.0        NaN  100.0   5.0             NaN            6.6
# 35       2.0  1.0        NaN  104.0   4.0             NaN            8.4
# 40       1.0  1.0        NaN   88.0   5.0             3.0            6.5
# 43       1.0  1.0        NaN  120.0   4.0             2.0           67.0
# 45       2.0  1.0        NaN  120.0   5.0             3.0            6.5
# 52       2.0  1.0        NaN    NaN   1.0             NaN            7.7
# 56       1.0  1.0        NaN    NaN   NaN             NaN            6.7
# ...

# %% [markdown]
# #### Выводы пропущенные значения.
#
#  В данной точке я бы остановилась и проигнорировала все остальные пропуски, т.к. неизвестна задача исследования. В таком контексте замена, например, пропущенных значений температуры  на среднее может привести к неправильным выводам во время анализа.
#  В столбце  abd_appearance больше половины пропущенных значений (55%), гипотетически его можно удалить в случае, если эти показатели не имеют критического значения для анализа.
#
#  В целях выполнения ДЗ сформируем датафрейм, в котором пропуски будут отсутствовать.
#
#  1  Удаляем строки, в которых половина данных отсутствует.
#  2  Решения по столбцам:
#
# surgery - 0.3% - 1 строка, удаляем
#
# age - 8.0% - заменим обратно на 'no data', чтобы видеть эту группу с недостаточными данными ( возможно это значение 2)
#
# rect_temp - 20.0% - здесь мода - 38, медиана - 38,2 и среднее  арифм- 38,16 достаточно близки, пропуски заменим на среднее арифм.
#
# pulse - 8.0% - заменим на средн. арифметическое
#
# pain - 18.3% - категориальная величина, меняем на моду - 3.
#
# abd_appearance - 55.0% - т.к. больше половины данных отсутствует, удаляем столбец
#
# total_protein - 11.0% - меняем на средн. арифметическое
#
# outcome - 0.3% - 1 строка, удаляем

# %%
df_dz1[df_dz1['pulse'].isnull()]
# Out:
#      surgery  age  rect_temp  pulse  pain  abd_appearance  total_protein  \
# 52       2.0  1.0        NaN    NaN   1.0             NaN            7.7
# 58       1.0  1.0        NaN    NaN   5.0             3.0            5.9
# 78       1.0  1.0        NaN    NaN   5.0             NaN            5.9
# 83       1.0  1.0       38.0    NaN   5.0             NaN            7.8
# 93       2.0  1.0        NaN    NaN   5.0             NaN            6.5
# 115      2.0  1.0        NaN    NaN   3.0             NaN           70.0
# 117      2.0  1.0       39.5    NaN   3.0             1.0            6.7
# 126      1.0  1.0       38.7    NaN   5.0             2.0            6.5
# 136      1.0  1.0        NaN    NaN   5.0             NaN            5.9
# 151      1.0  1.0       39.3    NaN   4.0             3.0            NaN
# 159      2.0  1.0        NaN    NaN   2.0             2.0            7.5
# 160      1.0  1.0        NaN    NaN   4.0             2.0           58.0
# ...

# %%
df_dz1.dropna(thresh=5, inplace=True)

# %%
df_dz1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   surgery         287 non-null    float64
#  1   age             287 non-null    object
#  2   rect_temp       287 non-null    float64
#  3   pulse           273 non-null    float64
#  4   pain            242 non-null    float64
#  5   abd_appearance  133 non-null    float64
#  6   total_protein   262 non-null    float64
#  7   outcome         287 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 20.2+ KB

# %%
df_dz1.age.fillna('no_data', inplace=True)

# %%
df_dz1.rect_temp.fillna(df_dz1.rect_temp.mean(), inplace=True)

# %%
df_dz1.pulse.fillna(df_dz1.pulse.mean(), inplace=True)

# %%
df_dz1.pain.fillna(df_dz1.pain.mode()[0], inplace=True)

# %%
df_dz1.drop(['abd_appearance'], axis=1, inplace=True)

# %%
df_dz1.total_protein.fillna(df_dz1.total_protein.mean(), inplace=True)

# %%
df_dz1.describe()
# Out:
#           surgery   rect_temp       pulse        pain  total_protein  \
# count  287.000000  287.000000  287.000000  287.000000     287.000000
# mean     1.404181   38.164286   71.714286    2.954704      24.542748
# std      0.491590    0.666549   27.692853    1.203740      26.256546
# min      1.000000   35.400000   30.000000    1.000000       3.300000
# 25%      1.000000   37.800000   48.000000    2.000000       6.600000
# 50%      1.000000   38.164286   66.000000    3.000000       7.700000
# 75%      2.000000   38.500000   88.000000    4.000000      54.500000
# max      2.000000   40.800000  184.000000    5.000000      89.000000
#
#           outcome
# count  287.000000
# mean     1.550523
# std      0.740953
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
df_dz1
# Out:
#      surgery      age  rect_temp  pulse  pain  total_protein  outcome
# 0        2.0        1  38.500000   66.0   5.0       8.400000      2.0
# 1        1.0        1  39.200000   88.0   3.0      85.000000      3.0
# 2        2.0        1  38.300000   40.0   3.0       6.700000      1.0
# 3        1.0  no_data  39.100000  164.0   2.0       7.200000      2.0
# 4        2.0        1  37.300000  104.0   3.0       7.400000      2.0
# ..       ...      ...        ...    ...   ...            ...      ...
# 295      1.0        1  38.164286  120.0   2.0      65.000000      3.0
# 296      2.0        1  37.200000   72.0   4.0      24.542748      3.0
# 297      1.0        1  37.500000   72.0   4.0       6.800000      2.0
# 298      1.0        1  36.500000  100.0   3.0       6.000000      1.0
# 299      1.0        1  37.200000   40.0   3.0      62.000000      3.0
#
# [287 rows x 7 columns]
